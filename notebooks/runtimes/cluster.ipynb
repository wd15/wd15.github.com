# %% [markdown]
# # FiPy in Parallel on the Cluster
#
# Let's switch to running on a cluster to look at using FiPy on more parallel nodes. First, let's define a script to do the FiPy run time testing. The script uses `docopt` to parse the parameters passed from the shell command. Again, a diffusion equation is being solved on a 3D grid.

# %%
# %%writefile fipy_timing.py

"""
Usage: fipy_timing.py [-h] [--N N] [--iterations <iterations>] [--suite <suite>]

Options:
  -h --help                 Show this screen.
  --N=N                     Cell number is N^3 [default: 30]
  --iterations=<iterations> Number of iterations [default: 100]
  --suite=<suite>           Solver suite [default: trilinos]
  
"""

from docopt import docopt
import timeit
import numpy as np
import fipy as fp

arguments = docopt(__doc__, version='Run FiPy timing')
N = int(arguments['--N'])
iterations = int(arguments['--iterations'])
suite = arguments['--suite']

attempts = 3

setup_str = '''
import fipy as fp
import numpy as np
np.random.seed(1)
L = 1.
N = {N:d}
m = fp.GmshGrid3D(nx=N, ny=N, nz=N, dx=L / N, dy=L / N, dz=L / N)
v0 = 1.
for dim in range(3):
    x = np.linspace(0., L, N)
    fx = np.sum(np.array([np.sin(2 * x * np.pi * i * np.random.random()) / i for i in range(1, N)]), axis=0)
    v0 = np.outer(v0, fx).flatten()
v = fp.CellVariable(mesh=m)
v0 = np.resize(v0, len(v)) ## Gmsh doesn't always give us the correct sized grid!
eqn = fp.TransientTerm(1e-3) == fp.DiffusionTerm()
v[:] = v0.copy()

import fipy.solvers.{suite} as solvers
solver = solvers.linearPCGSolver.LinearPCGSolver(precon=None, iterations={iterations}, tolerance=1e-100)

eqn.solve(v, dt=1., solver=solver)
v[:] = v0.copy()
'''

timeit_str = '''
eqn.solve(v, dt=1., solver=solver)
fp.parallelComm.Barrier()
'''

timer = timeit.Timer(timeit_str, setup=setup_str.format(N=N, suite=suite, iterations=iterations))
times = timer.repeat(attempts, 1)

if fp.parallelComm.procID == 0:
    print min(times)
# Out:
# Overwriting fipy_timing.py

# %% [markdown]
# We also need a script to launch jobs on the cluster. The `NSLOTS` variable is generated by the queing system when the job is launched as a parallel job with
#
#      $ qsub -pe nodal <NSLOTS> -cwd -o <output_file> launcher  <N>  <iterations> <suite>
#
# for example.

# %%
# %%writefile launcher
#
# #!/bin/bash
# source ~/.bashrc
# mpirun -np $NSLOTS python fipy_timing.py --N=$1 --iterations=$2 --suite=$3
# Out:
# Overwriting launcher

# %%
# !chmod +x ./launcher

# %% [markdown]
# The following cell launches a multidimensional set of simulations on the cluster. The time is written to a file name based on the parameter values.

# %%
import itertools
 
Ns = (10, 20, 40, 80)
nps = (1, 2, 4, 8, 16, 24, 32, 48, 64)
suites = ('trilinos', 'pysparse')
iterations_ = (100, 200, 400, 800)

for N, iterations, np_, suite in itertools.product(Ns, iterations_, nps, suites):
    tmpfile = 'tmp-{0}-{1}-{2}-{3}.txt'.format(N, iterations, np_, suite)
    # !rm $tmpfile
    if suite == 'pysparse' and np_ > 1:
        pass
    else:
        # !qsub -pe nodal $np_ -cwd -o $tmpfile launcher $N $iterations $suite
# Out:
# rm: cannot remove `tmp-10-100-1-trilinos.txt': No such file or directory
# Your job 1719605 ("launcher") has been submitted
# rm: cannot remove `tmp-10-100
64-pysparse.txt': No such file or directory
# rm: cannot remove `tmp-80-400-1-trilinos.txt': No such file or directory
# Your job 1719745 ("launcher") has been submitted
# rm: cannot remove `tmp-80-400-1-pysparse.txt': No such file or directory
# Your job 1719746 ("launcher") has been submitted
# rm: cannot remove `tmp-80-400-2-trilinos.txt': No such file or directory
# Your job 1719747 ("launcher") has been submitted
# rm: cannot remove `tmp-80-400-2-pysparse.txt': No such file or directory
# rm: cannot remove `tmp-80-400-4-trilinos.txt': No such file or directory
# Your job 1719748 ("launcher") has been submitted
# rm: cannot remove `tmp-80-400-4-pysparse.txt': No such file or directory
# rm: cannot remove `tmp-80-400-8-trilinos.txt': No such file or directory
# Your job 1719749 ("launcher") has been submitted
# rm: cannot remove `tmp-80-400-8-pysparse.txt': No such file or directory
# rm: cannot remove `tmp-80-400-16-trilinos.txt': No such file or directory
# Your job 1719750 ("launcher") has been submitted
# rm: cannot remove `tmp-80-400-16-pysparse.txt': No such file or directory
# rm: cannot remove `tmp-80-400-24-trilinos.txt': No such file or directory
# Your job 1719751 ("launcher") has been submitted
# rm: cannot remove `tmp-80-400-24-pysparse.txt': No such file or directory
# rm: cannot remove `tmp-80-400-32-trilinos.txt': No such file or directory
# Your job 1719752 ("launcher") has been submitted
# rm: cannot remove `tmp-80-400-32-pysparse.txt': No such file or directory
# rm: cannot remove `tmp-80-400-48-trilinos.txt': No such file or directory
# Your job 1719753 ("launcher") has been submitted
# rm: cannot remove `tmp-80-400-48-pysparse.txt': No such file or directory
# rm: cannot remove `tmp-80-400-64-trilinos.txt': No such file or directory
# Your job 1719754 ("launcher") has been submitted
# rm: cannot remove `tmp-80-400-64-pysparse.txt': No such file or directory
# rm: cannot remove `tmp-80-800-1-trilinos.txt': No such file or directory
# Your job 1719755 ("launcher") has been submitted
# rm: cannot remove `tmp-80-800-1-pysparse.txt': No such file or directory
# Your job 1719756 ("launcher") has been submitted
# rm: cannot remove `tmp-80-800-2-trilinos.txt': No such file or directory
# Your job 1719757 ("launcher") has been submitted
# rm: cannot remove `tmp-80-800-2-pysparse.txt': No such file or directory
# rm: cannot remove `tmp-80-800-4-trilinos.txt': No such file or directory
# Your job 1719758 ("launcher") has been submitted
# rm: cannot remove `tmp-80-800-4-pysparse.txt': No such file or directory
# rm: cannot remove `tmp-80-800-8-trilinos.txt': No such file or directory
# Your job 1719759 ("launcher") has been submitted
# rm: cannot remove `tmp-80-800-8-pysparse.txt': No such file or directory
# rm: cannot remove `tmp-80-800-16-trilinos.txt': No such file or directory
# Your job 1719760 ("launcher") has been submitted
# rm: cannot remove `tmp-80-800-16-pysparse.txt': No such file or directory
# rm: cannot remove `tmp-80-800-24-trilinos.txt': No such file or directory
# Your job 1719761 ("launcher") has been submitted
# rm: cannot remove `tmp-80-800-24-pysparse.txt': No such file or directory
# rm: cannot remove `tmp-80-800-32-trilinos.txt': No such file or directory
# Your job 1719762 ("launcher") has been submitted
# rm: cannot remove `tmp-80-800-32-pysparse.txt': No such file or directory
# rm: cannot remove `tmp-80-800-48-trilinos.txt': No such file or directory
# Your job 1719763 ("launcher") has been submitted
# rm: cannot remove `tmp-80-800-48-pysparse.txt': No such file or directory
# rm: cannot remove `tmp-80-800-64-trilinos.txt': No such file or directory
# Your job 1719764 ("launcher") has been submitted
# rm: cannot remove `tmp-80-800-64-pysparse.txt': No such file or directory

# %%
# !qstat
# Out:
# job-ID  prior   name       user         state submit/start at     queue                          slots ja-task-ID
# -----------------------------------------------------------------------------------------------------------------
# 1719614 0.28826 launcher   wd15         qw    02/19/2014 15:38:41                                   64
# 1719624 0.18826 launcher   wd15         qw    02/19/2014 15:38:44                                   64
# 1719634 0.15492 launcher   wd15         qw    02/19/2014 15:38:48                                   64
# 1719644 0.13825 launcher   wd15         qw    02/19/2014 15:38:51                                   64
# 1719654 0.12825 launcher   wd15         qw    02/19/2014 15:38:54                                   64
# 1719664 0.12159 launcher   wd15         qw    02/19/2014 15:38:58                                   64
# 1719674 0.11682 launcher   wd15         qw    02/19/2014 15:39:01                                   64
# 1719684 0.11325 launcher   wd15         qw    02/19/2014 15:39:04                                   64
# 1719694 0.11047 launcher   wd15         qw    02/19/2014 15:39:08                                   64
# 1719704 0.10825 launcher   wd15         qw    02/19/2014 15:39:11                                   64
# 1719714 0.10643 launcher   wd15         qw    02/19/2014 15:39:15                                   64
# 1719724 0.10491 launcher   wd15         qw    02/19/2014 15:39:18                                   64
# 1719734 0.10363 launcher   wd15         qw    02/19/2014 15:39:22                                   64
# 1719744 0.10253 launcher   wd15         qw    02/19/2014 15:39:25                                   64
# 1719754 0.10158 launcher   wd15         qw    02/19/2014 15:39:29                                   64
# 1719764 0.10074 launcher   wd15         qw    02/19/2014 15:39:32                                   64

# %% [markdown]
# The following cell post processes the data into a csv file, which is saved in version control.

# %%
import os
import pandas as pd

def getdata():
    for f in os.listdir(os.getcwd()):
        if f.endswith('.txt') and f.startswith('tmp'): 
            try:
                run_time = float(open(f).read())
            except:
                run_time = 1000.0
            values = f.strip('.txt').strip('tmp').split('-')[1:]
            fs = (int, int, int, str)
            data = [x(y) for x, y in zip(fs, values)]
            data.append(run_time)
            yield data

df = pd.DataFrame(columns=['iterations', 'N', 'np', 'run time', 'suite'])
for N, iterations, np_, suite, run_time in getdata():
    df = df.append({'N' : N, 'iterations' : iterations, 'np' : np_, 'suite' : suite, 'run time' : run_time}, ignore_index=True)

df.to_csv('laptop_runtimes_cluster.csv')

# %%
df = pd.read_csv('laptop_runtimes_cluster.csv', index_col=0)

# %%
Ns = sorted(set(df['N']))
iterations_ = sorted(set(df['iterations']))

def ax_iter(Ns, iterations_):
    f = plt.figure(figsize=(6 * 3, 6 * 2))
    for i, N in enumerate(Ns):
        ax = f.add_subplot(2, 3, i + 1)
        for iterations in iterations_:
            yield ax, N, iterations   
        ax.set_title('$N={0}$'.format(N))
        ax.set_ylabel("Speed Up")
        ax.set_xlabel("Parallel Nodes")
        ax.legend(loc="upper left")
        ax.set_ylim(ymax=64)
        ax.set_ylim(ymin=0.5)
        ax.set_xlim(xmin=0.9)
        ax.set_xlim(xmax=64)
        ax.loglog((1, 64), (1, 64), 'k--')
        ax.legend(loc="upper left")
    
for ax, N, iterations in ax_iter(Ns, iterations_):
    df_sub = df[(df['iterations'] == iterations) & (df['N'] == N)]
    df_tril = df_sub[df_sub['suite'] == 'trilinos'].sort('np')
    df_pysp = df_sub[df_sub['suite'] == 'pysparse'].sort('np')

    nprocs = np.array(df_tril['np'])
    run_times = np.array(df_tril['run time'])
    
    run_time_pysp = np.array(df_pysp['run time'])

    if len(run_times) > 0:
        line = ax.loglog(nprocs, run_times[0] / run_times, label='iterations={0}'.format(iterations))
    if len(run_time_pysp) > 0:
        ax.loglog((1,), (run_times[0] / run_time_pysp[0],), line[0].get_c() + 'o', label='pysparse')

# %% [markdown]
# The speed up graphs above correspond to different sized domains, each
# with $N^3$ cells. Each curve represents a different number of
# iterations in the solver. The dots represent the speed when switching to the
# PySparse solver suite (serial only). Currently results are only available up to 48
# nodes. The cluster is still queuing jobs that require 64 nodes. The
# maximum number of slots that can be requested with the cluster is 64.
# The 64 node jobs have been queuing for a day.
#
# The results show quite good scaling for the larger problems. The two
# smallest grid sizes have a high proportion of overlap cells and thus
# too much communication overhead. PySparse is better than Trilinos for
# the smaller systems, but is within a factor of 2 for the larger
# systems. In the the `N=40` graph there is a considerable slow down at
# 24 and 32 nodes. This kind of variation may be due to jobs running on
# machines with a shared load and communication overhead (any machine
# may have multiple separate parallel jobs). It is possible to request
# 64 slots or even a specific machine for each job, but would require long
# waits in the queue.
#
# Further work should check the reproducibility of these
# results. Currently the best of three time steps is used for each
# job. A better approach may be to launch multiple instances of the
# same job so that jobs are launched on different machines with alternative shared loads. The data shown here represents the first
# set of runs that worked in terms of execution and post-processing.
